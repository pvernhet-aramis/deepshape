# %%
### Base ###
import os
import sys
import numpy as np 
import torch 
import torch.nn as nn
from torch.optim import Adam
import fnmatch
from torch.utils.data import TensorDataset, DataLoader
import itertools
import math
from sklearn.decomposition import PCA
import PIL.Image as pimg
import scipy

### Visualization ###
#import seaborn as sns
#sns.set(color_codes=True)
import matplotlib.cm as cm
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from matplotlib import rc
rc('text', usetex=True)
rc('font', **{'family':'serif','serif':['Palatino']})

# %%
### Deepshape ### 
path_to_deepshape = '/Users/alexandre.bone/Softwares/deepshape/src'
sys.path = [path_to_deepshape] + [elt for elt in sys.path if 'deformetrica' not in elt]

from support.nets_iclr import *

# %% [markdown]
# # 0. Functions

# %%
def load_eyes_black(number_of_images_train, number_of_images_test, random_seed=None):

#     path_to_train = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_black/train'
#     path_to_test = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_black/test'
    
#     path_to_train = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_black__blurred_2-5/train'
#     path_to_test = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_black__blurred_2-5/test'

#     path_to_train = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_regular/train__blurred_2-5'
#     path_to_test = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_regular/test__blurred_2-5'

#     path_to_train = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_regular/train'
#     path_to_test = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_regular/test'
    
#     path_to_train = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_final/train_32'
#     path_to_test = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_final/test_32'

#    path_to_train = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_final/train_32__2160'
#    path_to_test = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_final/test_32__2160'

#     path_to_train = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_final/train_32__2160_denser'
#     path_to_test = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_final/test_32__2160_denser'

#     path_to_train = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_final/train_32__2160_denser_smaller'
#     path_to_test = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_final/test_32__2160_denser_smaller'

#     path_to_train = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_final/train_32__2160_denser_bis'
#     path_to_test = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_final/test_32__2160_denser_bis'

#     path_to_train = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_final/train_32__1296_denser'
#     path_to_test = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_final/test_32__1296_denser'

#     path_to_train = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_final/train_32__1440_denser'
#     path_to_test = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_final/test_32__1440_denser'

#     path_to_train = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_final_2/train'
#     path_to_test = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_final_2/test'

    path_to_train = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_final_4/train'
    path_to_test = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/data_final_4/test'

    # Train
    intensities_train = []
    elts = sorted([_ for _ in os.listdir(path_to_train) if _[:3] == 'eye'], key=(lambda x: int(x.split('_')[-1][:-4])))
    for elt in elts:
        img = np.array(pimg.open(os.path.join(path_to_train, elt)))
        intensities_train.append(torch.from_numpy(img).float())
    intensities_train = torch.stack(intensities_train)

    assert number_of_images_train <= intensities_train.size(0), \
        'Too many required files. A maximum of %d are available' % intensities_train.size(0)
    intensities_train = intensities_train[:number_of_images_train]

    # Test
    intensities_test = []
    elts = sorted([_ for _ in os.listdir(path_to_test) if _[:3] == 'eye'], key=(lambda x: int(x.split('_')[-1][:-4])))
    for elt in elts:
        img = np.array(pimg.open(os.path.join(path_to_test, elt)))
        intensities_test.append(torch.from_numpy(img).float())
    intensities_test = torch.stack(intensities_test)

    assert number_of_images_test <= intensities_test.size(0), \
        'Too many required files. A maximum of %d are available' % intensities_test.size(0)
    intensities_test = intensities_test[:number_of_images_test]

    # Finalize
    intensities_template = torch.mean(intensities_train, dim=0)

    intensities_mean = float(torch.mean(intensities_train).detach().cpu().numpy())
    intensities_std = float(torch.std(intensities_train).detach().cpu().numpy())
    intensities_train = ((intensities_train - intensities_mean) / intensities_std).unsqueeze(1)
    intensities_test = ((intensities_test - intensities_mean) / intensities_std).unsqueeze(1)
    intensities_template = ((intensities_template - intensities_mean) / intensities_std).unsqueeze(0)

    return intensities_train, intensities_test, intensities_template, intensities_mean, intensities_std

class MetamorphicAtlas__JN(nn.Module):

    def __init__(self, template_intensities, number_of_time_points, downsampling_factor,
                 latent_dimension__s, latent_dimension__a,
                 kernel_width__s, kernel_width__a,
                 initial_lambda_square__s=1., initial_lambda_square__a=1.):
        nn.Module.__init__(self)

        self.decode_count = 0

        self.dimension = len(template_intensities.size()) - 1
        self.latent_dimension__s = latent_dimension__s
        self.latent_dimension__a = latent_dimension__a

        self.downsampling_factor = downsampling_factor
        self.grid_size = template_intensities.size(1)
        self.downsampled_grid_size = self.grid_size // self.downsampling_factor
        assert self.grid_size == template_intensities.size(2)
        
        self.v_star_average = torch.zeros((self.dimension, self.downsampled_grid_size, self.downsampled_grid_size))
        self.n_star_average = torch.zeros((1, self.grid_size, self.grid_size))

        self.number_of_time_points = number_of_time_points
        self.dt = 1. / float(number_of_time_points - 1)

        self.kernel_width__s = kernel_width__s
        self.kernel_width__a = kernel_width__a

        # self.template_intensities = template_intensities
        self.template_intensities = nn.Parameter(template_intensities)
        print('>> Template intensities are %d ** %d = %d parameters' % (
            template_intensities.size(1), self.dimension, template_intensities.view(-1).size(0)))

        if self.dimension == 2:
            if downsampling_factor == 1:
                self.encoder = Encoder2d__final(self.grid_size, latent_dimension__s, latent_dimension__a,
                                                init_var__s=(initial_lambda_square__s / np.sqrt(latent_dimension__s)),
                                                init_var__a=(initial_lambda_square__a / np.sqrt(latent_dimension__a)))
            else:
                self.encoder = Encoder2d__5_down(self.grid_size, latent_dimension__s, latent_dimension__a,
                                                 init_var__s=(initial_lambda_square__s / np.sqrt(latent_dimension__s)),
                                                 init_var__a=(initial_lambda_square__a / np.sqrt(latent_dimension__a)))

            self.decoder__s = DeepDecoder2d__final(latent_dimension__s, 2, self.downsampled_grid_size)
            if downsampling_factor == 1:
                self.decoder__a = DeepDecoder2d__final(latent_dimension__a, 1, self.grid_size)
            else:
                self.decoder__a = DeepDecoder2d__5_up(latent_dimension__a, 1, self.grid_size)
                #self.decoder__a = DeepDecoder2d__4_up(latent_dimension__a, 1, self.grid_size)

        elif self.dimension == 3:
            assert False
            # self.encoder = Encoder3d(self.splatting_grid_size, self.latent_dimension,
            #                          init_var=initial_lambda_square / np.sqrt(latent_dimension))
            # self.decoder = DeepDecoder3d(self.latent_dimension, self.deformation_grid_size)

        else:
            raise RuntimeError

        print('>> BayesianAtlas has {} parameters'.format(sum([len(elt.view(-1)) for elt in self.parameters()])))

    def encode(self, x):
        """
        x -> z
        """ 
#        return self.encoder(x)

        return self.encoder(x - self.template_intensities.detach())

#         means__s, log_variances__s, means__a, log_variances__a = self.encoder(x)
#         mean__st, log_variance__st, mean__at, log_variance__at = self.encoder(self.template_intensities.detach().unsqueeze(0))
#         return (means__s - mean__st.detach().expand(means__s.size()), log_variances__s,
#                 means__a - mean__at.detach().expand(means__a.size()), log_variances__a)

    def decode(self, s, a):
        """
        z -> y
        """

        # INIT
        bts = s.size(0)
        assert bts == a.size(0)
        ntp = self.number_of_time_points
        kws = self.kernel_width__s
        kwa = self.kernel_width__a
        dim = self.dimension
        gs = self.grid_size
        dgs = self.downsampled_grid_size
        dsf = self.downsampling_factor

        # DECODE
        # s = z[:, :self.latent_dimension__s]
        # a = z[:, -self.latent_dimension__a:]

        v_star = self.decoder__s(s) - self.v_star_average.type(str(s.type()))
        n_star = self.decoder__a(a) - self.n_star_average.type(str(a.type()))

        # GAUSSIAN SMOOTHING
        v = batched_vector_smoothing(v_star, kws, scaled=False)
        n = batched_scalar_smoothing(n_star, kwa, scaled=False)

        # NORMALIZE
        s_norm_squared = torch.sum(s ** 2, dim=1)
        a_norm_squared = torch.sum(a ** 2, dim=1)
        v_norm_squared = torch.sum(v * v_star, dim=tuple(range(1, dim + 2)))
        n_norm_squared = torch.sum(n * n_star, dim=tuple(range(1, dim + 2)))
        normalizer__s = torch.where(s_norm_squared > 1e-10,
                                    torch.sqrt(s_norm_squared / v_norm_squared),
                                    torch.from_numpy(np.array(0.0)).float().type(str(s.type())))
        normalizer__a = torch.where(a_norm_squared > 1e-10,
                                    torch.sqrt(a_norm_squared / n_norm_squared),
                                    torch.from_numpy(np.array(0.0)).float().type(str(a.type())))

        if dim == 2:
            normalizer__s = normalizer__s.view(bts, 1, 1, 1).expand(v.size())
            normalizer__a = normalizer__a.view(bts, 1, 1, 1).expand(n.size())
        elif dim == 3:
            assert False
            # normalizer = normalizer.view(bts, 1, 1, 1, 1).expand(v.size())
        v = v * normalizer__s
        n = n * normalizer__a

        if self.decode_count < 10:
            print('>> normalizer shape  = %.3E ; max(abs(v)) = %.3E' %
                  (normalizer__s.detach().cpu().numpy().reshape(-1)[0], np.max(np.abs(v.detach().cpu().numpy()))))
            print('>> normalizer appea  = %.3E ; max(abs(n)) = %.3E' %
                  (normalizer__a.detach().cpu().numpy().reshape(-1)[0], np.max(np.abs(n.detach().cpu().numpy()))))
            print('torch.max(n) = %.3f \n' % torch.max(n))
            self.decode_count += 1

        # FLOW
        grid = torch.stack(torch.meshgrid(
            [torch.linspace(0.0, gs - 1.0, dgs),
             torch.linspace(0.0, gs - 1.0, dgs)])).type(str(s.type())).view(1, 2, dgs, dgs).repeat(bts, 1, 1, 1)

        x = grid.clone() + v / float(2 ** ntp)
        for t in range(ntp):
            x += batched_vector_interpolation(x - grid, x, dsf)

        # INTERPOLATE
        intensities = batched_scalar_interpolation(self.template_intensities + n, x)
        # intensities = batched_scalar_interpolation(self.template_intensities + n * 0, x)

        return intensities

    def forward(self, s, a):
        # print('>> Please avoid this forward method.')
        return self.decode(s, a)

# %% [markdown]
# # 1. Load network

# %%
#path_to_results = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/25__ldim_2_2__kw_10_2__data_final_2__20k_epochs__no_centering__5_up'
#path_to_results = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/25__ldim_2_2__kw_10_2__data_final_2__10k_epochs__no_centering__5_up'

#path_to_results = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/25__ldim_2_2__kw_10_2__data_final_2__20k_epochs__fixed_template__5_up'
#path_to_results = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/25__ldim_2_2__kw_10_2__data_final_2__20k_epochs__fixed_template__5_up__added_template'

#path_to_results = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/27__ldim_2_2__kw_10_2__data_final_2__20k_epochs__no_centering__5_up__noise_aug'
#path_to_results = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/27__ldim_2_2__kw_10_2__data_final_2__20k_epochs__no_centering__5_up'

#path_to_results = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/28__ldim_2_2__kw_10_2__data_final_4__10k_epochs__no_centering__5_up'
#path_to_results = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/28__ldim_2_2__kw_10_2__data_final_4__10k_epochs__no_centering__5_up__batch_960'
#path_to_results = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/28__ldim_2_2__kw_10_2__data_final_4__10k_epochs__no_centering__5_up__lr_4'
#path_to_results = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/28__ldim_2_2__kw_10_2__data_final_4__10k_epochs__no_centering__5_up__lr_4__ls_0-5'

#path_to_results = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/29__ldim_2_2__kw_10_2__data_final_4__10k_epochs__no_centering__5_up__no_bias_encoder'
path_to_results = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/29__ldim_2_2__kw_10_2__data_final_4__10k_epochs__no_centering__5_up__no_bias_encoder__ls_0-1_0-5'
#path_to_results = '/Users/alexandre.bone/Softwares/deepshape/examples/eyes/29__ldim_2_2__kw_10_2__data_final_4__10k_epochs__no_centering__5_up__no_bias_encoder__ls_0-1_0-5__fixed_template'

# Load state dict 
path_to_state_dict = os.path.join(
    path_to_results, 
    sorted(fnmatch.filter(os.listdir(path_to_results), 'model__epoch_5000*'), key=(lambda x: int(x.split('_')[-1][:-4])))[-1])
print('path_to_state_dict = %s' % os.path.basename(path_to_state_dict))
state_dict = torch.load(path_to_state_dict, map_location=lambda storage, loc: storage)

# Lead centering parameters
path_to_v_star_average = os.path.join(path_to_results, 'vsa__epoch_%s.npy' % (os.path.basename(path_to_state_dict).split('_')[-1][:-4]))
path_to_n_star_average = os.path.join(path_to_results, 'nsa__epoch_%s.npy' % (os.path.basename(path_to_state_dict).split('_')[-1][:-4]))
if os.path.isfile(path_to_v_star_average):
    print('path_to_v_star_average = %s' % os.path.basename(path_to_v_star_average))
    v_star_average = torch.from_numpy(np.load(path_to_v_star_average))
else: 
    print('v_star_average set to zero')
    dgs = state_dict.get('template_intensities').numpy().shape[-1] // 2
    v_star_average = torch.zeros((2, dgs, dgs))
if os.path.isfile(path_to_n_star_average):
    print('path_to_n_star_average = %s' % os.path.basename(path_to_n_star_average))
    n_star_average = torch.from_numpy(np.load(path_to_n_star_average))
else: 
    print('n_star_average set to zero')
    n_star_average = torch.zeros(state_dict.get('template_intensities').size())
# Out:
# path_to_state_dict = model__epoch_5000.pth
# path_to_v_star_average = vsa__epoch_5000.npy
# path_to_n_star_average = nsa__epoch_5000.npy

# %%
# GLOBALS
# output_dir = os.path.join(os.path.dirname(__file__), '../../../examples/brats', experiment_prefix)

#number_of_images_train = 1296
number_of_images_train = 10000
number_of_images_test = 0

downsampling_factor = 2
number_of_time_points = 5

dimension = 2
latent_dimension__s = 2
latent_dimension__a = 2

kernel_width__s = 10
kernel_width__a = 2

lambda_square__s = 1. ** 2
lambda_square__a = 0.5 ** 2
noise_variance = 0.01 ** 2

# DATA 
(intensities_train, intensities_test, intensities_template, intensities_mean, intensities_std) = load_eyes_black(
            number_of_images_train, number_of_images_test, random_seed=42)

# SET WEIGHTS
model = MetamorphicAtlas__JN(
        intensities_template, number_of_time_points, downsampling_factor,
        latent_dimension__s, latent_dimension__a,
        kernel_width__s, kernel_width__a,
        initial_lambda_square__s=lambda_square__s, initial_lambda_square__a=lambda_square__a)
model.load_state_dict(state_dict)
model.v_star_average = v_star_average
model.n_star_average = n_star_average
model.decode_count = 100

noise_dimension = model.grid_size ** model.dimension

# PRINT TEMPLATE
img = model.template_intensities.detach().cpu().numpy()[0]

figsize = 5
f = plt.figure(figsize=(figsize, figsize))
plt.imshow(img, cmap='gray')
plt.axis('off')
plt.title('Learned template')
plt.show()
# Out:
# >> Template intensities are 32 ** 2 = 1024 parameters
# >> Encoder2d__final has 3816 parameters
# >> DeepDecoder2d__final has 3264 parameters
# >> DeepDecoder2d__5_up has 7344 parameters
# >> BayesianAtlas has 15448 parameters

# %% [markdown]
# # 2. Qualitative analysis

# %%
indexes = np.random.RandomState(seed=42).permutation(number_of_images_train)[:15]
# indexes = [0, 1, 2, 3, 4]
# indexes = np.random.permutation(number_of_images_train)[:5]

##############
### DEFORM ###
##############

mean = intensities_mean
std = intensities_std
observations = intensities_train.clone()

s, _, a, _ = model.encode(observations)

# INIT
bts = s.size(0)
assert bts == a.size(0)
ntp = model.number_of_time_points
kws = model.kernel_width__s
kwa = model.kernel_width__a
dim = model.dimension
gs = model.grid_size
dgs = model.downsampled_grid_size
dsf = model.downsampling_factor

# DECODE
# s = z[:, :model.latent_dimension__s]
# a = z[:, -model.latent_dimension__a:]

v_star = model.decoder__s(s) - model.v_star_average.type(str(s.type()))
n_star = model.decoder__a(a) - model.n_star_average.type(str(a.type()))

# GAUSSIAN SMOOTHING
v = batched_vector_smoothing(v_star, kws, scaled=False)
n = batched_scalar_smoothing(n_star, kwa, scaled=False)

# NORMALIZE
s_norm_squared = torch.sum(s ** 2, dim=1)
a_norm_squared = torch.sum(a ** 2, dim=1)
v_norm_squared = torch.sum(v * v_star, dim=tuple(range(1, dim + 2)))
n_norm_squared = torch.sum(n * n_star, dim=tuple(range(1, dim + 2)))
normalizer__s = torch.where(s_norm_squared > 1e-10,
                            torch.sqrt(s_norm_squared / v_norm_squared),
                            torch.from_numpy(np.array(0.0)).float().type(str(s.type())))
normalizer__a = torch.where(a_norm_squared > 1e-10,
                            torch.sqrt(a_norm_squared / n_norm_squared),
                            torch.from_numpy(np.array(0.0)).float().type(str(a.type())))

if dim == 2:
    normalizer__s = normalizer__s.view(bts, 1, 1, 1).expand(v.size())
    normalizer__a = normalizer__a.view(bts, 1, 1, 1).expand(n.size())
elif dim == 3:
    assert False
    # normalizer = normalizer.view(bts, 1, 1, 1, 1).expand(v.size())
v = v * normalizer__s
n = n * normalizer__a


# FLOW
grid = torch.stack(torch.meshgrid(
    [torch.linspace(0.0, gs - 1.0, dgs),
     torch.linspace(0.0, gs - 1.0, dgs)])).type(str(s.type())).view(1, 2, dgs, dgs).repeat(bts, 1, 1, 1)

x = grid.clone() + v / float(2 ** ntp)
for t in range(ntp):
    x += batched_vector_interpolation(x - grid, x, dsf)

# INTERPOLATE
intensities = batched_scalar_interpolation(model.template_intensities + n, x)

# WRITE
template = mean + std * model.template_intensities.clone()

images = []
images_ = []
for i in range(bts):
    appearance = mean + std * (model.template_intensities + n[i])
    shape = mean + std * batched_scalar_interpolation(model.template_intensities, x[i].unsqueeze(0))[0]
    metamorphosis = mean + std * intensities[i]
    target = mean + std * observations[i]

    images_i = [template, appearance, shape, metamorphosis, target]
    images_ += images_i
    images.append(images_i)
images_ = torch.cat(images_)
# vmax = torch.max(images_).detach().numpy()
vmax = torch.max(images_[indexes]).detach().numpy()

################
### RESIDUAL ###
################

empiric_noise_std = torch.sqrt(torch.sum((intensities - observations) ** 2) / float(intensities.size(0) * noise_dimension)).detach().cpu().numpy()
print('empiric_noise_std = %.2E' % empiric_noise_std)

############
### PLOT ###
############

# indexes = np.random.permutation(number_of_images_train)[:5]
# indexes = [0]

figsize = 4
nrows = len(indexes)
ncols = len(images_i) + 1
f, axes = plt.subplots(nrows, ncols , figsize=(ncols*figsize, nrows*figsize))
for i in range(nrows):
    for j in range(ncols):
        ax = axes.reshape(nrows, ncols)[i, j]
        index = indexes[i]

        if j == ncols-1: 
            img = (images[index][j-1] - images[index][j-2]).detach().cpu().numpy()[0] 
            ax.imshow(img, cmap='seismic')
            
        else: 
            img = images[index][j].detach().cpu().numpy()[0]
            if j != 2:
                ax.imshow(img, cmap='gray', vmin=0.0, vmax=vmax)

            if j == 2:
                g = x[index].permute(1, 2, 0).detach().cpu().numpy()
                ax.plot([g[:-1, :, 0].ravel(), g[1:, :, 0].ravel()], 
                        [g[:-1, :, 1].ravel(), g[1:, :, 1].ravel()], 'grey', linewidth=0.5)
                ax.plot([g[:, :-1, 0].ravel(), g[:, 1:, 0].ravel()],
                        [g[:, :-1, 1].ravel(), g[:, 1:, 1].ravel()], 'grey', linewidth=0.5)

                X = grid[index].permute(1, 2, 0).view(-1, 2).detach().cpu().numpy()
                V = v[index].permute(1, 2, 0).view(-1, 2).detach().cpu().numpy()
                ax.quiver(X[:, 0], X[:, 1], V[:, 0], V[:, 1], color='tab:blue', scale=25, width=0.007)
                
                dxy = 5
                ax.set_xlim((- dxy, gs - 1.0 + dxy))
                ax.set_ylim((- dxy, gs - 1.0 + dxy))
        
        ax.axis('off')
plt.show()

f.savefig('5_eyes_reconstructions.pdf', bbox_inches='tight')

# save_image(images_.unsqueeze(1),'5_eyes_reconstructions.pdf',
#            nrow=5, normalize=True, range=(0., float(torch.max(images_).detach().cpu().numpy())))
# Out:
# empiric_noise_std = 8.07E-02

# %%
v.size()
# Out:
# torch.Size([10000, 2, 16, 16])

# %%
figsize = 5
nrows = 2
ncols = 3

f, axes = plt.subplots(nrows, ncols , figsize=(ncols*figsize, nrows*figsize))

# Learned template
template = model.template_intensities.detach().cpu().numpy()[0]
img = template
img = intensities_mean + intensities_std * img
# img_ = np.copy(img)
ax = axes[0, 0]
ax.imshow(img, cmap='gray', vmin=0.0, vmax=vmax)
ax.axis('off')
ax.set_title('Learned template')

# Average intensity increment
n_average = torch.mean(n, dim=0)[0].detach().cpu().numpy()
img = n_average
ax = axes[0, 1]
ax.imshow(img, cmap='coolwarm')
ax.axis('off')
ax.set_title('Average intensity increment')

# Difference
img = template + n_average
img = intensities_mean + intensities_std * img
ax = axes[0, 2]
ax.imshow(img, cmap='gray', vmin=0.0, vmax=vmax)
ax.axis('off')
ax.set_title('Template + Average increment')

# Learned template + increment
img = template + n_average
img = intensities_mean + intensities_std * img
ax = axes[1, 0]
ax.imshow(img, cmap='gray', vmin=0.0, vmax=vmax)
ax.axis('off')
ax.set_title('Template + Average increment')

# Average deformation
x_average = torch.mean(x, dim=0)
g = x_average.permute(1, 2, 0).detach().cpu().numpy()
ax = axes[1, 1]
ax.plot([g[:-1, :, 0].ravel(), g[1:, :, 0].ravel()], 
        [g[:-1, :, 1].ravel(), g[1:, :, 1].ravel()], 'grey', linewidth=0.5)
ax.plot([g[:, :-1, 0].ravel(), g[:, 1:, 0].ravel()],
        [g[:, :-1, 1].ravel(), g[:, 1:, 1].ravel()], 'grey', linewidth=0.5)
dxy = 5
ax.set_xlim((- dxy, gs - 1.0 + dxy))
ax.set_ylim((- dxy, gs - 1.0 + dxy))
ax.axis('off')
ax.set_title('Average deformation')

# Difference
img = batched_scalar_interpolation(model.template_intensities + torch.mean(n, dim=0), 
                                   x_average.unsqueeze(0))[0].detach().cpu().numpy()[0]
img = intensities_mean + intensities_std * img
ax = axes[1, 2]
ax.imshow(img, cmap='gray', vmin=0.0, vmax=vmax)
ax.axis('off')
ax.set_title('Deformed template + Average deformation')

plt.show()
f.savefig('5_eyes_template.pdf', bbox_inches='tight')


# Save rectified template
tol = 1e-10
# img = (np.clip((img - np.min(img)) / (np.max(img) - np.min(img)), tol, 1.0 - tol) * 255).astype('uint8')
img = (np.clip(img, tol, 255.0 - tol)).astype('uint8')
pimg.fromarray(img).save('5_eyes_rectified_template.png')

# %%
index = np.random.RandomState(seed=42).permutation(number_of_images_train)[0]

img = n[index, 0].detach().cpu().numpy() - n_average
img = img - np.mean(img)

figsize = 5
f = plt.figure(figsize=(figsize, figsize))
plt.imshow(img, cmap='coolwarm')
plt.axis('off')
# plt.title('Learned template')
plt.show()




thresholds = [0.95, 0.85, 0.75, 0.65, 0.55, 0.54, 0.53, 0.52, 0.51, 0.50]
figsize = 4
ncols = min(len(thresholds), 5)
nrows = len(thresholds) // ncols

f, axes = plt.subplots(nrows, ncols , figsize=(ncols*figsize, nrows*figsize))
for k, c in enumerate(thresholds):
    ax = np.ravel(axes)[k]

    mi = np.min(img)
    ma = np.max(img)
    img_thres = 1.0 * (img > mi + c * (ma - mi)) - 1.0 * (img < ma - c * (ma - mi))

    ax.imshow(img_thres, cmap='coolwarm')
    ax.axis('off')
    ax.set_title('c = %.2f' % c)

plt.show()
f.savefig('5_eyes_segmentation.pdf', bbox_inches='tight')

# %%
zs = s.detach().cpu().numpy()
za = a.detach().cpu().numpy()

figsize = 8
ncols = 2
nrows = 1
f, axes = plt.subplots(nrows, ncols , figsize=(ncols*figsize, nrows*figsize))

### SHAPE 

nn = 6 
if number_of_images_train == 10000: 
    nn = 10

pca_s = PCA(2)
zs = pca_s.fit_transform(zs)
zsm = np.mean(zs.reshape((nn * nn, nn * nn, 2)), axis=1)

ax = axes.ravel()[0]
cmap = cm.get_cmap('tab20')
palette = np.random.RandomState(seed=42).permutation(np.arange(nn * nn))

ax.scatter(zs[:, 0], zs[:, 1], s=10, cmap=cmap, c=np.kron(palette, np.ones((nn * nn,))))
ax.scatter(zsm[:, 0], zsm[:, 1], s=200, marker='o', cmap=cmap, c=palette)

g = zsm.reshape((nn, nn, 2))
ax.plot([g[:-1, :, 0].ravel(), g[1:, :, 0].ravel()], 
        [g[:-1, :, 1].ravel(), g[1:, :, 1].ravel()], 'k', linewidth=2.)
ax.plot([g[:, :-1, 0].ravel(), g[:, 1:, 0].ravel()],
        [g[:, :-1, 1].ravel(), g[:, 1:, 1].ravel()], 'k', linewidth=2.)

zsref_0 = np.array([0.0, 0.0])
zsref_t = pca_s.transform(model.encode(model.template_intensities.unsqueeze(0))[0].detach().numpy())[0]
#zsref_t = model.encode(model.template_intensities.unsqueeze(0))[0].detach().numpy()[0]
ax.scatter(zsref_0[0], zsref_0[1], marker='+', s=400, c='k', linewidth=3)
ax.scatter(zsref_t[0], zsref_t[1], marker='x', s=400, c='k', linewidth=3)

ax.grid()
ax.set_title('shape')


### APPEARANCE
pca_a = PCA(2)
za = pca_a.fit_transform(za)
zam = np.mean(za.reshape((nn * nn, nn * nn, 2)), axis=0)

ax = axes.ravel()[1]
cmap = cm.get_cmap('tab20')
palette = np.random.RandomState(seed=42).permutation(np.arange(nn * nn))

ax.scatter(za[:, 0], za[:, 1], s=10, cmap=cmap, c=np.kron(np.ones((nn * nn,)), palette))
ax.scatter(zam[:, 0], zam[:, 1], s=200, marker='o', cmap=cmap, c=palette)

g = zam.reshape((nn, nn, 2))
ax.plot([g[:-1, :, 0].ravel(), g[1:, :, 0].ravel()], 
        [g[:-1, :, 1].ravel(), g[1:, :, 1].ravel()], 'k', linewidth=2.)
ax.plot([g[:, :-1, 0].ravel(), g[:, 1:, 0].ravel()],
        [g[:, :-1, 1].ravel(), g[:, 1:, 1].ravel()], 'k', linewidth=2.)

zaref_0 = np.array([0.0, 0.0])
zaref_t = pca_a.transform(model.encode(model.template_intensities.unsqueeze(0))[2].detach().numpy())[0]
#zaref_t = model.encode(model.template_intensities.unsqueeze(0))[2].detach().numpy()[0]
ax.scatter(zaref_0[0], zaref_0[1], marker='+', s=400, c='k', linewidth=3)
ax.scatter(zaref_t[0], zaref_t[1], marker='x', s=400, c='k', linewidth=3)

ax.grid()
#ax.axis('equal')
ax.set_title('appearance')

plt.tight_layout()
plt.show()
f.savefig('5_eyes_latent_spaces.pdf', bbox_inches='tight')

# %%
model.encode(model.template_intensities.unsqueeze(0))[0].detach().numpy()
# Out:
# array([[0., 0.]], dtype=float32)

# %%
pca_s.transform(model.encode(model.template_intensities.unsqueeze(0))[0].detach().numpy())[0]
# Out:
# array([0.8250065 , 0.07214096], dtype=float32)

# %%
pca_s.components_
# Out:
# array([[ 0.5810677 ,  0.81385523],
#        [-0.81385523,  0.5810677 ]], dtype=float32)

# %%
index_a = np.random.RandomState(seed=42).permutation(number_of_images_train)[7]
index_b = np.random.RandomState(seed=42).permutation(number_of_images_train)[6]
T = 6

zs = s.detach().cpu().numpy()
za = a.detach().cpu().numpy()

figsize = 8
ncols = 2
nrows = 1
f, axes = plt.subplots(nrows, ncols , figsize=(ncols*figsize, nrows*figsize))

### SHAPE 
pca_s = PCA(2)
zs = pca_s.fit_transform(zs)
zsm = np.mean(zs.reshape((nn * nn, nn * nn, 2)), axis=1)

ax = axes.ravel()[0]
cmap = cm.get_cmap('tab20')
palette = np.random.RandomState(seed=42).permutation(np.arange(nn * nn))
alpha = 0.1

ax.scatter(zs[:, 0], zs[:, 1], s=10, cmap=cmap, c=np.kron(palette, np.ones((nn * nn,))), alpha=alpha)
ax.scatter(zsm[:, 0], zsm[:, 1], s=200, marker='o', cmap=cmap, c=palette, alpha=alpha)

g = zsm.reshape((nn, nn, 2))
ax.plot([g[:-1, :, 0].ravel(), g[1:, :, 0].ravel()], 
        [g[:-1, :, 1].ravel(), g[1:, :, 1].ravel()], 'k', linewidth=2., alpha=alpha)
ax.plot([g[:, :-1, 0].ravel(), g[:, 1:, 0].ravel()],
        [g[:, :-1, 1].ravel(), g[:, 1:, 1].ravel()], 'k', linewidth=2., alpha=alpha)

t = np.repeat(np.linspace(0.0, 1.0, T).reshape((-1, 1)), 2, axis=1)
zst = zs[index_a] + t * (zs[index_b] - zs[index_a])
ax.scatter(zst[:, 0], zst[:, 1], s=200, c='k')
for i, tt in enumerate(t):
    xlims = ax.get_xlim()
    ylims = ax.get_ylim()
    dxytext = np.array([- 0.03 * (xlims[1] - xlims[0]), 0.03 * (ylims[1] - ylims[0])])
    ax.text(zst[i, 0] + dxytext[0], zst[i, 1] + dxytext[1], 't=%.2f' % (tt[0]), fontsize=15)

ax.grid()
ax.set_title('shape')


### APPEARANCE
pca_a = PCA(2)
za = pca_a.fit_transform(za)
zam = np.mean(za.reshape((nn * nn, nn * nn, 2)), axis=0)
zamm = np.mean(zam.reshape((nn, nn, 2)), axis=1)
              
ax = axes.ravel()[1]
cmap = cm.get_cmap('tab20')
palette = np.random.RandomState(seed=42).permutation(np.arange(nn * nn))
alpha = 0.1

ax.scatter(za[:, 0], za[:, 1], s=10, cmap=cmap, c=np.kron(np.ones((nn * nn,)), palette), alpha=alpha)
ax.scatter(zam[:, 0], zam[:, 1], s=200, marker='o', cmap=cmap, c=palette, alpha=alpha)

g = zam.reshape((nn, nn, 2))
ax.plot([g[:-1, :, 0].ravel(), g[1:, :, 0].ravel()], 
        [g[:-1, :, 1].ravel(), g[1:, :, 1].ravel()], 'k', linewidth=2., alpha=alpha)
ax.plot([g[:, :-1, 0].ravel(), g[:, 1:, 0].ravel()],
        [g[:, :-1, 1].ravel(), g[:, 1:, 1].ravel()], 'k', linewidth=2., alpha=alpha)

t = np.repeat(np.linspace(0.0, 1.0, T).reshape((-1, 1)), 2, axis=1)
zat = za[index_a] + t * (za[index_b] - za[index_a])
ax.scatter(zat[:, 0], zat[:, 1], s=200, c='k')
for i, tt in enumerate(t):
    xlims = ax.get_xlim()
    ylims = ax.get_ylim()
    dxytext = np.array([- 0.03 * (xlims[1] - xlims[0]), 0.03 * (ylims[1] - ylims[0])])
    ax.text(zat[i, 0] + dxytext[0], zat[i, 1] + dxytext[1], 't=%.2f' % (tt[0]), fontsize=15)
ax.grid()
ax.set_title('appearance')

plt.tight_layout()
plt.show()
#f.savefig('5_eyes_latent_spaces.pdf', bbox_inches='tight')


##############################
##############################
##############################


### 
### INTERPOLATION
###

s_start = s[index_a]
a_start = a[index_a]
s_end = s[index_b]
a_end = a[index_b]

dt = 1.0 / float(T-1)

imgs = torch.Tensor()
tol = 1e-10

# MIXED INTERPOLATION
st = torch.from_numpy(pca_s.inverse_transform(zst)).float()
at = torch.from_numpy(pca_a.inverse_transform(zat)).float()
img = torch.clamp(intensities_mean + intensities_std * model(st, at), tol, 255. - tol)
imgs = torch.cat((imgs, img))

# APPEARANCE INTERPOLATION
st = s_start.unsqueeze(0).repeat(T, 1)
at = torch.from_numpy(pca_a.inverse_transform(zat)).float()
img = torch.clamp(intensities_mean + intensities_std * model(st, at), tol, 255. - tol)
imgs = torch.cat((imgs, img))

# SHAPE INTERPOLATION
st = torch.from_numpy(pca_s.inverse_transform(zst)).float()
at = a_start.unsqueeze(0).repeat(T, 1)
img = torch.clamp(intensities_mean + intensities_std * model(st, at), tol, 255. - tol)
imgs = torch.cat((imgs, img))

save_image(imgs, '5_eyes_interpolation_linear.pdf', 
           nrow=T, normalize=True, range=(0., float(torch.max(imgs).detach().cpu().numpy())))

figsize = 4
ncols = T
nrows = len(imgs) // ncols

f, axes = plt.subplots(nrows, ncols , figsize=(ncols*figsize, nrows*figsize))
for k, img in enumerate(imgs):
    ax = np.ravel(axes)[k]
    ax.imshow(img.detach().cpu().numpy()[0], cmap='gray', vmin=0.0, vmax=vmax)
    ax.axis('off')
    ax.set_title('t = %.2f' % ((k % T) * dt), fontsize=25)
plt.show()

# %%
# INTERPOLATION ISO-NORM

def cart2pol(v):
    x, y = v
    rho = np.sqrt(x**2 + y**2)
    phi = np.arctan2(y, x)
    return(rho, phi)

def pol2cart(rho, phi):
    x = rho * np.cos(phi)
    y = rho * np.sin(phi)
    return np.array([x, y])

index_a = np.random.RandomState(seed=42).permutation(number_of_images_train)[7]
index_b = np.random.RandomState(seed=42).permutation(number_of_images_train)[6]
T = 6

zs = s.detach().cpu().numpy()
za = a.detach().cpu().numpy()

figsize = 8
ncols = 2
nrows = 1
f, axes = plt.subplots(nrows, ncols , figsize=(ncols*figsize, nrows*figsize))

### SHAPE 
pca_s = PCA(2)
zs = pca_s.fit_transform(zs)
zsm = np.mean(zs.reshape((nn * nn, nn * nn, 2)), axis=1)

ax = axes.ravel()[0]
cmap = cm.get_cmap('tab20')
palette = np.random.RandomState(seed=42).permutation(np.arange(nn * nn))
alpha = 0.1

ax.scatter(zs[:, 0], zs[:, 1], s=10, cmap=cmap, c=np.kron(palette, np.ones((nn * nn,))), alpha=alpha)
ax.scatter(zsm[:, 0], zsm[:, 1], s=200, marker='o', cmap=cmap, c=palette, alpha=alpha)

g = zsm.reshape((nn, nn, 2))
ax.plot([g[:-1, :, 0].ravel(), g[1:, :, 0].ravel()], 
        [g[:-1, :, 1].ravel(), g[1:, :, 1].ravel()], 'k', linewidth=2., alpha=alpha)
ax.plot([g[:, :-1, 0].ravel(), g[:, 1:, 0].ravel()],
        [g[:, :-1, 1].ravel(), g[:, 1:, 1].ravel()], 'k', linewidth=2., alpha=alpha)

zsref_0 = np.array([0.0, 0.0])
zsref_t = pca_s.transform(model.encode(model.template_intensities.unsqueeze(0))[0].detach().numpy())[0]
#ax.scatter(zsref_0[0], zsref_0[1], marker='+', s=400, c='k', linewidth=3)
ax.scatter(zsref_t[0], zsref_t[1], marker='x', s=400, c='k', linewidth=3)

#zsref = zsref_t
zsref = zsref_0
zs0_r, zs0_t = cart2pol(zs[index_a] - zsref)
zs1_r, zs1_t = cart2pol(zs[index_b] - zsref)
t = np.linspace(0.0, 1.0, T).reshape((-1, 1))
zst_r = zs0_r + t * (zs1_r - zs0_r)
theta = zs1_t - zs0_t
theta = (2 * np.pi + theta) * (theta < 0) + theta * (theta > 0)
if math.sin(theta) >= 0: 
    zst_t = zs0_t + t * theta
else: 
    zst_t = zs0_t - t * (2 * math.pi - theta)
zst = np.array([zsref + pol2cart(float(rho), float(phi)) for (rho, phi) in zip(zst_r, zst_t)])

ax.scatter(zsref[0], zsref[1], marker='+', s=400, c='k', linewidth=3)
ax.scatter(zst[:, 0], zst[:, 1], s=200, c='k')
for i, tt in enumerate(t):
    xlims = ax.get_xlim()
    ylims = ax.get_ylim()
    dxytext = np.array([- 0.03 * (xlims[1] - xlims[0]), 0.03 * (ylims[1] - ylims[0])])
    ax.text(zst[i, 0] + dxytext[0], zst[i, 1] + dxytext[1], 't=%.2f' % (tt[0]), fontsize=15)

ax.grid()
ax.set_title('shape')


### APPEARANCE
pca_a = PCA(2)
za = pca_a.fit_transform(za)
zam = np.mean(za.reshape((nn * nn, nn * nn, 2)), axis=0)
zamm = np.mean(zam.reshape((nn, nn, 2)), axis=1)
              
ax = axes.ravel()[1]
cmap = cm.get_cmap('tab20')
palette = np.random.RandomState(seed=42).permutation(np.arange(nn * nn))
alpha = 0.1

ax.scatter(za[:, 0], za[:, 1], s=10, cmap=cmap, c=np.kron(np.ones((nn * nn,)), palette), alpha=alpha)
ax.scatter(zam[:, 0], zam[:, 1], s=200, marker='o', cmap=cmap, c=palette, alpha=alpha)

g = zam.reshape((nn, nn, 2))
ax.plot([g[:-1, :, 0].ravel(), g[1:, :, 0].ravel()], 
        [g[:-1, :, 1].ravel(), g[1:, :, 1].ravel()], 'k', linewidth=2., alpha=alpha)
ax.plot([g[:, :-1, 0].ravel(), g[:, 1:, 0].ravel()],
        [g[:, :-1, 1].ravel(), g[:, 1:, 1].ravel()], 'k', linewidth=2., alpha=alpha)

zaref_0 = np.array([0.0, 0.0])
zaref_t = pca_a.transform(model.encode(model.template_intensities.unsqueeze(0))[2].detach().numpy())[0]
#ax.scatter(zaref_0[0], zaref_0[1], marker='+', s=400, c='k', linewidth=3)
ax.scatter(zaref_t[0], zaref_t[1], marker='x', s=400, c='k', linewidth=3)

#zaref = zaref_t
zaref = zaref_0
za0_r, za0_t = cart2pol(za[index_a] - zaref)
za1_r, za1_t = cart2pol(za[index_b] - zaref)
t = np.linspace(0.0, 1.0, T).reshape((-1, 1))
zat_r = za0_r + t * (za1_r - za0_r)
theta = za1_t - za0_t
theta = (2 * np.pi + theta) * (theta < 0) + theta * (theta > 0)
if math.sin(theta) >= 0: 
    zat_t = za0_t + t * theta
else: 
    zat_t = za0_t - t * (2 * math.pi - theta)
zat = np.array([zaref + pol2cart(float(rho), float(phi)) for (rho, phi) in zip(zat_r, zat_t)])

ax.scatter(zaref[0], zaref[1], marker='+', s=400, c='k', linewidth=3)
ax.scatter(zat[:, 0], zat[:, 1], s=200, c='k')
for i, tt in enumerate(t):
    xlims = ax.get_xlim()
    ylims = ax.get_ylim()
    dxytext = np.array([- 0.03 * (xlims[1] - xlims[0]), 0.03 * (ylims[1] - ylims[0])])
    ax.text(zat[i, 0] + dxytext[0], zat[i, 1] + dxytext[1], 't=%.2f' % (tt[0]), fontsize=15)
ax.grid()
ax.set_title('appearance')

plt.tight_layout()
plt.show()
#f.savefig('5_eyes_latent_spaces.pdf', bbox_inches='tight')


##############################
##############################
##############################


### 
### INTERPOLATION BY ELLIPSES 
###

s_start = s[index_a]
a_start = a[index_a]
s_end = s[index_b]
a_end = a[index_b]

dt = 1.0 / float(T-1)

imgs = torch.Tensor()
tol = 1e-10

# MIXED INTERPOLATION
st = torch.from_numpy(pca_s.inverse_transform(zst)).float()
at = torch.from_numpy(pca_a.inverse_transform(zat)).float()
img = torch.clamp(intensities_mean + intensities_std * model(st, at), tol, 255. - tol)
imgs = torch.cat((imgs, img))

# APPEARANCE INTERPOLATION
st = s_start.unsqueeze(0).repeat(T, 1)
at = torch.from_numpy(pca_a.inverse_transform(zat)).float()
img = torch.clamp(intensities_mean + intensities_std * model(st, at), tol, 255. - tol)
imgs = torch.cat((imgs, img))

# SHAPE INTERPOLATION
st = torch.from_numpy(pca_s.inverse_transform(zst)).float()
at = a_start.unsqueeze(0).repeat(T, 1)
img = torch.clamp(intensities_mean + intensities_std * model(st, at), tol, 255. - tol)
imgs = torch.cat((imgs, img))

save_image(imgs, '5_eyes_interpolation_isonorm.pdf', 
           nrow=T, normalize=True, range=(0., float(torch.max(imgs).detach().cpu().numpy())))


figsize = 4
ncols = T
nrows = len(imgs) // ncols

f, axes = plt.subplots(nrows, ncols , figsize=(ncols*figsize, nrows*figsize))
for k, img in enumerate(imgs):
    ax = np.ravel(axes)[k]
    ax.imshow(img.detach().cpu().numpy()[0], cmap='gray', vmin=0.0, vmax=vmax)
    ax.axis('off')
    ax.set_title('t = %.2f' % ((k % T) * dt), fontsize=25)
plt.show()

# %%
(2 * math.pi - theta) * 180. / math.pi
# Out:
# 178.01113136065646

# %%
theta * 180. / math.pi
# Out:
# 181.9888686393435

# %%
za0_r, za0_t * 180. / math.pi, za1_r, za1_t * 180. / math.pi
# Out:
# (5.935453034079523,
#  21.637252106853612,
#  3.3648542323543396,
#  -156.37387925380284)

# %%
zs1_t * 180. / math.pi, zs0_t * 180. / math.pi
# Out:
# (-44.81327373878083, 67.2100918295823)

# %%
math.sin(theta)
# Out:
# -0.03470533550086436

# %%
zsref = zsref_0
zs0_r, zs0_t = cart2pol(zs[index_a] - zsref)
zs1_r, zs1_t = cart2pol(zs[index_b] - zsref)
t = np.linspace(0.0, 1.0, T).reshape((-1, 1))
zst_r = zs0_r + t * (zs1_r - zs0_r)
zst_t = zs0_t - t * (2 * math.pi - (zs1_t - zs0_t))

# %%
[elt * 180. / math.pi for elt in zs0_t + t * (zs1_t - zs0_t)]
# Out:
# [array([67.21009183]),
#  array([44.80541872]),
#  array([22.4007456]),
#  array([-0.00392751]),
#  array([-22.40860063]),
#  array([-44.81327374])]

# %%
angles = zs1_t - zs0_t
(2*np.pi + angles) * (angles < 0) + angles*(angles > 0)
# Out:
# 4.328008738846401

# %%
zs = s.detach().cpu().numpy()
za = a.detach().cpu().numpy()

figsize = 8
ncols = 2
nrows = 1
f, axes = plt.subplots(nrows, ncols , figsize=(ncols*figsize, nrows*figsize))

### SHAPE 
pca_s = PCA(2)
zs = pca_s.fit_transform(zs)
zsm = np.mean(zs.reshape((nn * nn, nn * nn, 2)), axis=1)

ax = axes.ravel()[0]
cmap = cm.get_cmap('tab20')
palette = np.random.RandomState(seed=42).permutation(np.arange(nn * nn))

ax.scatter(zs[:, 0], zs[:, 1], s=10, cmap=cmap, c=np.kron(palette, np.ones((nn * nn,))))
ax.scatter(zsm[:, 0], zsm[:, 1], s=200, marker='o', cmap=cmap, c=palette)

g = zsm.reshape((nn, nn, 2))
ax.plot([g[:-1, :, 0].ravel(), g[1:, :, 0].ravel()], 
        [g[:-1, :, 1].ravel(), g[1:, :, 1].ravel()], 'k', linewidth=2.)
ax.plot([g[:, :-1, 0].ravel(), g[:, 1:, 0].ravel()],
        [g[:, :-1, 1].ravel(), g[:, 1:, 1].ravel()], 'k', linewidth=2.)


ax.grid()
ax.set_title('shape')


### APPEARANCE
pca_a = PCA(2)
za = pca_a.fit_transform(za)
zam = np.mean(za.reshape((nn * nn, nn * nn, 2)), axis=0)
zamm = np.mean(zam.reshape((nn, nn, 2)), axis=1)
              
ax = axes.ravel()[1]
cmap = cm.get_cmap('tab20')
palette = np.random.RandomState(seed=42).permutation(np.arange(nn * nn))
alpha = 0.1

ax.scatter(za[:, 0], za[:, 1], s=10, cmap=cmap, c=np.kron(np.ones((nn * nn,)), palette), alpha=alpha)
ax.scatter(zam[:, 0], zam[:, 1], s=200, marker='o', cmap=cmap, c=palette, alpha=alpha)

g = zam.reshape((nn, nn, 2))
ax.plot([g[:-1, :, 0].ravel(), g[1:, :, 0].ravel()], 
        [g[:-1, :, 1].ravel(), g[1:, :, 1].ravel()], 'k', linewidth=2., alpha=alpha)
ax.plot([g[:, :-1, 0].ravel(), g[:, 1:, 0].ravel()],
        [g[:, :-1, 1].ravel(), g[:, 1:, 1].ravel()], 'k', linewidth=2., alpha=alpha)

ax.scatter(zamm[:, 0], zamm[:, 1], s=500, marker='o', c='k')
for i in range(nn):
    xlims = ax.get_xlim()
    ylims = ax.get_ylim()
    dxytext = np.array([- 0.03 * (xlims[1] - xlims[0]), 0.05 * (ylims[1] - ylims[0])])
    ax.text(zamm[i, 0] + dxytext[0], zamm[i, 1] + dxytext[1], 'A%d' % (i + 1), fontsize=25)

ax.grid()
ax.set_title('appearance')

plt.tight_layout()
plt.show()
#f.savefig('5_eyes_latent_spaces.pdf', bbox_inches='tight')


################################
################################
################################

tol = 1e-10
a_am = torch.from_numpy(pca_a.inverse_transform(zamm))
s_am = torch.zeros(a_am.size())
imgs = torch.clamp(intensities_mean + intensities_std * model(s_am, a_am), tol, 255. - tol)[:, 0].detach().cpu().numpy()
#imgs = torch.clamp(intensities_mean + intensities_std * (model(s_am, a_am) - model.template_intensities), tol, 255. - tol)[:, 0].detach().cpu().numpy()

figsize = 4
ncols = 5
nrows = 2
f, axes = plt.subplots(nrows, ncols , figsize=(ncols*figsize, nrows*figsize))

for k, img in enumerate(imgs):
    ax = axes.ravel()[k]
    ax.imshow(img, cmap='gray', vmin=0.0, vmax=vmax)
    ax.axis('off')
    ax.set_title('A%d' % (k+1), fontsize=25)
    
plt.tight_layout()
plt.show()
f.savefig('5_eyes_appearance_latent_space.pdf', bbox_inches='tight')

# %%
zs = s.detach().cpu().numpy()
za = a.detach().cpu().numpy()

figsize = 8
ncols = 2
nrows = 1
f, axes = plt.subplots(nrows, ncols , figsize=(ncols*figsize, nrows*figsize))

### SHAPE 
pca_s = PCA(2)
zs = pca_s.fit_transform(zs)
zsm = np.mean(zs.reshape((nn * nn, nn * nn, 2)), axis=1)

ax = axes.ravel()[0]
cmap = cm.get_cmap('tab20')
palette = np.random.RandomState(seed=42).permutation(np.arange(nn * nn))

ax.scatter(zs[:, 0], zs[:, 1], s=10, cmap=cmap, c=np.kron(palette, np.ones((nn * nn,))))
ax.scatter(zsm[:, 0], zsm[:, 1], s=200, marker='o', cmap=cmap, c=palette)

g = zsm.reshape((nn, nn, 2))
ax.plot([g[:-1, :, 0].ravel(), g[1:, :, 0].ravel()], 
        [g[:-1, :, 1].ravel(), g[1:, :, 1].ravel()], 'k', linewidth=2.)
ax.plot([g[:, :-1, 0].ravel(), g[:, 1:, 0].ravel()],
        [g[:, :-1, 1].ravel(), g[:, 1:, 1].ravel()], 'k', linewidth=2.)


ax.grid()
ax.set_title('shape')


### APPEARANCE
pca_a = PCA(2)
za = pca_a.fit_transform(za)
zam = np.mean(za.reshape((nn * nn, nn * nn, 2)), axis=0)
zamm = np.mean(zam.reshape((nn, nn, 2)), axis=1)
              
ax = axes.ravel()[1]
cmap = cm.get_cmap('tab20')
palette = np.random.RandomState(seed=42).permutation(np.arange(nn * nn))
alpha = 0.1

ax.scatter(za[:, 0], za[:, 1], s=10, cmap=cmap, c=np.kron(np.ones((nn * nn,)), palette), alpha=alpha)
ax.scatter(zam[:, 0], zam[:, 1], s=200, marker='o', cmap=cmap, c=palette, alpha=alpha)

g = zam.reshape((nn, nn, 2))
ax.plot([g[:-1, :, 0].ravel(), g[1:, :, 0].ravel()], 
        [g[:-1, :, 1].ravel(), g[1:, :, 1].ravel()], 'k', linewidth=2., alpha=alpha)
ax.plot([g[:, :-1, 0].ravel(), g[:, 1:, 0].ravel()],
        [g[:, :-1, 1].ravel(), g[:, 1:, 1].ravel()], 'k', linewidth=2., alpha=alpha)

grid_a = np.moveaxis(np.array(np.meshgrid(np.linspace(-5, 5, 6), np.linspace(-2.5, 2.5, 6)[::-1])), 0, 2).reshape(-1, 2)
ax.scatter(grid_a[:, 0], grid_a[:, 1], s=400, marker='o', c='k')
#k = 0
#for i in range(grid_a.shape[0]):
#    for j in range(grid_a.shape[1]):
#        xlims = ax.get_xlim()
#        ylims = ax.get_ylim()
#        dxytext = np.array([- 0.03 * (xlims[1] - xlims[0]), 0.05 * (ylims[1] - ylims[0])])
#        ax.text(grid_a[i, j, 0] + dxytext[0], grid_a[i, j, 1] + dxytext[1], 'A%d' % (k + 1), fontsize=20)
#        k += 1
for k, grid_a_ij in enumerate(grid_a):
    xlims = ax.get_xlim()
    ylims = ax.get_ylim()
    dxytext = np.array([- 0.03 * (xlims[1] - xlims[0]), 0.05 * (ylims[1] - ylims[0])])
    ax.text(grid_a_ij[0] + dxytext[0], grid_a_ij[1] + dxytext[1], 'A%d' % (k + 1), fontsize=20)

ax.grid()
ax.set_title('appearance')

plt.tight_layout()
plt.show()
#f.savefig('5_eyes_latent_spaces.pdf', bbox_inches='tight')


################################
################################
################################

tol = 1e-10
a_am = torch.from_numpy(pca_a.inverse_transform(grid_a)).float()
s_am = torch.zeros(a_am.size())
imgs = torch.clamp(intensities_mean + intensities_std * model(s_am, a_am), tol, 255. - tol)[:, 0].detach().cpu().numpy()
#imgs = torch.clamp(intensities_mean + intensities_std * (model(s_am, a_am) - model.template_intensities), tol, 255. - tol)[:, 0].detach().cpu().numpy()

figsize = 4
ncols = 6
nrows = 6
f, axes = plt.subplots(nrows, ncols , figsize=(ncols*figsize, nrows*figsize))

for k, img in enumerate(imgs):
    ax = axes.ravel()[k]
    ax.imshow(img, cmap='gray', vmin=0.0, vmax=vmax)
    ax.axis('off')
    ax.set_title('A%d' % (k+1), fontsize=25)
    
plt.tight_layout()
plt.show()
f.savefig('5_eyes_appearance_latent_space_2.pdf', bbox_inches='tight')
